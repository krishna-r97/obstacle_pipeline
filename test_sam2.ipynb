# %%
from ultralytics import SAM

# %%
image_path = "./test_images/81a0d0e1-c5b4-4c86-88ce-4ed478b12ee6.png"

# %%
model = SAM("sam2.1_b.pt")

# %%
result = model(image_path)

# %%
# Save the result image with masks
result[0].save(filename="result_with_mask.jpg")
# Out:
# 'result_with_mask.jpg'
